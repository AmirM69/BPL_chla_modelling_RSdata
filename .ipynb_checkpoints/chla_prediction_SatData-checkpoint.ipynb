# %%
# from pymasker import LandsatMasker
# from pymasker import LandsatConfidence

# # load the QA band directly
# #
# # The "collection" parameter is required for landsat to specify the collection
# # number. Acceptable number: 0 (pre-collection), 1 (collection-1)
# #
# masker = LandsatMasker(r'..\Data\raw sat images-2014-2019\LC08_L1TP_036025_20170403_20170414_01_T1\LC08_L1TP_036025_20170403_20170414_01_T1_BQA.TIF', collection=1)

# # algorithm has high confidence that this condition exists
# # (67-100 percent confidence)
# conf = LandsatConfidence.low

# # Get mask indicating cloud pixels with high confidence
# mask = masker.get_snow_mask(conf)

# # save the result
# masker.save_tif(mask, 'result10.tif')

# %%
# Run this code in conda environment "MDN" to make MDN part working correctly.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows' ,50)

# %% [markdown]
# #  field chla data preparation

# %%
field_data = pd.read_csv('../Data/BP_data.csv', skiprows=[1], parse_dates=['Date'], index_col= 'SampleID')
field_data
# Out:
#               Dataset       Date         Time  SiteNumber   latitude  \
# SampleID
# 1                Buoy 2014-06-11   6:15:00 PM           1  50.586139
# 2                Buoy 2014-06-11   6:30:00 PM           1  50.586139
# 3                Buoy 2014-06-11   6:45:00 PM           1  50.586139
# 4                Buoy 2014-06-11   7:00:00 PM           1  50.586139
# 5                Buoy 2014-06-11   7:15:00 PM           1  50.586139
# ...               ...        ...          ...         ...        ...
# 110085    Calibration 2019-08-30  11:37:00 AM           1  50.586139
# 110086    Calibration 2019-09-03  12:05:00 PM           1  50.586139
# 110087    Calibration 2019-09-03  12:05:00 PM           1  50.586139
# 110088    Calibration 2019-09-03  12:05:00 PM           1  50.586139
# 110089    Calibration 2019-09-03  12:05:00 PM           1  50.586139
#
#            Longitude  BottomDepth  sampledepth  SecchiDiskDepth  \
# SampleID
# 1        -105.384833          4.3          NaN              NaN
# 2        -105.384833          4.3          NaN              NaN
# 3        -105.384833          4.3          NaN              NaN
# 4        -105.384833          4.3          NaN              NaN
# 5        -105.384833          4.3          NaN              NaN
# ...              ...          ...          ...              ...
# 110085   -105.384833          4.3          3.5              NaN
# 110086   -105.384833          4.3          0.0              NaN
# 110087   -105.384833          4.3          0.8              NaN
# 110088   -105.384833          4.3          2.8              NaN
# 110089   -105.384833          4.3          3.5              NaN
#
#           SamplingInScum  ...  Diatom_Synedra  Diatom_Cocconeis  \
# SampleID                  ...
# 1                    NaN  ...             NaN               NaN
# 2                    NaN  ...             NaN               NaN
# 3                    NaN  ...             NaN               NaN
# 4                    NaN  ...             NaN               NaN
# 5                    NaN  ...             NaN               NaN
# ...                  ...  ...             ...               ...
# 110085               NaN  ...             NaN               NaN
# 110086               NaN  ...             NaN               NaN
# 110087               NaN  ...             NaN               NaN
# 110088               NaN  ...             NaN               NaN
# 110089               NaN  ...             NaN               NaN
#
#           Diatom_Nitzchia  Diatom_Navicula  Diatom_Fragillaria  \
# SampleID
# 1                     NaN              NaN                 NaN
# 2                     NaN              NaN                 NaN
# 3                     NaN              NaN                 NaN
# 4                     NaN              NaN                 NaN
# 5                     NaN              NaN                 NaN
# ...                   ...              ...                 ...
# 110085                NaN              NaN                 NaN
# 110086                NaN              NaN                 NaN
# 110087                NaN              NaN                 NaN
# 110088                NaN              NaN                 NaN
# 110089                NaN              NaN                 NaN
#
#           Diatom_Tabellaria  Diatom_Gomphenema  Diatom_Astrionella  \
# SampleID
# 1                       NaN                NaN                 NaN
# 2                       NaN                NaN                 NaN
# 3                       NaN                NaN                 NaN
# 4                       NaN                NaN                 NaN
# 5                       NaN                NaN                 NaN
# ...                     ...                ...                 ...
# 110085                  NaN                NaN                 NaN
# 110086                  NaN                NaN                 NaN
# 110087                  NaN                NaN                 NaN
# 110088                  NaN                NaN                 NaN
# 110089                  NaN                NaN                 NaN
#
#           Flagellates  Other
# SampleID
# 1                 NaN    NaN
# 2                 NaN    NaN
# 3                 NaN    NaN
# 4                 NaN    NaN
# 5                 NaN    NaN
# ...               ...    ...
# 110085            NaN    NaN
# 110086            NaN    NaN
# 110087            NaN    NaN
# 110088            NaN    NaN
# 110089            NaN    NaN
#
# [110090 rows x 104 columns]

# %%
#buoy calibration
filt_dataset = field_data['Dataset'] == 'Buoy'
field_data.loc[filt_dataset, 'Lab_Chla'] = (5 * field_data[filt_dataset]['BGAPCShallowRFU']) ** (100/99)
field_data['Lab_Chla'].head()
# Out:
# SampleID
# 1    18.533269
# 2    17.493540
# 3    16.454429
# 4    19.053354
# 5    16.454429
# Name: Lab_Chla, dtype: float64

# %%
# drop the buoy observations associated with biofouling error
field_data = field_data[field_data['shallow_sonde_biofouling_outlier'] != 1].copy()
# drop the associated column 
field_data.drop('shallow_sonde_biofouling_outlier', axis=1, inplace=True)

# %%
# drop the lab observations labeld as error
field_data = field_data[field_data.Lab_chlaOutlier != 1].copy()
# drop the associated column 
field_data.drop('Lab_chlaOutlier', axis=1, inplace=True)
field_data.shape
# Out:
# (108778, 102)

# %%
# drop the observations containing bottom signal
field_data = field_data[~(field_data.SecchiDiskDepth >= field_data.BottomDepth)].copy()
field_data.shape
# Out:
# (108754, 102)

# %%
# averaging field chla data over date and station
chl_data = field_data.groupby(['Date', 'SiteNumber', 'latitude', 'Longitude']).agg({'Lab_Chla' :'median'})
chl_data
# Out:
#                                               Lab_Chla
# Date       SiteNumber latitude  Longitude
# 2014-01-06 2          50.585203 -105.385823        NaN
# 2014-01-13 2          50.585203 -105.385823   6.000000
# 2014-01-20 2          50.585203 -105.385823        NaN
# 2014-01-27 2          50.585203 -105.385823   7.000000
# 2014-02-03 2          50.585203 -105.385823        NaN
# ...                                                ...
# 2019-09-29 1          50.586139 -105.384833  38.898296
# 2019-09-30 1          50.586139 -105.384833  39.946201
# 2019-10-01 1          50.586139 -105.384833  39.946201
# 2019-10-02 1          50.586139 -105.384833  39.946201
# 2019-10-03 1          50.586139 -105.384833  41.518573
#
# [1394 rows x 1 columns]

# %%
# drop (dates,stations) with no chla measured
chl_data.dropna(axis=0, inplace=True)
chl_data
# Out:
#                                               Lab_Chla
# Date       SiteNumber latitude  Longitude
# 2014-01-13 2          50.585203 -105.385823   6.000000
# 2014-01-27 2          50.585203 -105.385823   7.000000
# 2014-02-10 2          50.585203 -105.385823  19.000000
# 2014-02-24 2          50.585203 -105.385823  14.000000
# 2014-03-10 2          50.585203 -105.385823   8.000000
# ...                                                ...
# 2019-09-29 1          50.586139 -105.384833  38.898296
# 2019-09-30 1          50.586139 -105.384833  39.946201
# 2019-10-01 1          50.586139 -105.384833  39.946201
# 2019-10-02 1          50.586139 -105.384833  39.946201
# 2019-10-03 1          50.586139 -105.384833  41.518573
#
# [1208 rows x 1 columns]

# %%
chl_data.reset_index(level=['Date', 'SiteNumber', 'latitude', 'Longitude'], inplace=True)
chl_data.index
chl_data.dtypes
# Out:
# Date          datetime64[ns]
# SiteNumber             int64
# latitude             float64
# Longitude            float64
# Lab_Chla             float64
# dtype: object

# %% [markdown]
# # Extract satelite data

# %%
# create a dataframe for images in the directory
import os, fnmatch

listOfFiles = os.listdir('../Data/L8_img_AC_acolite_2014-2019')
pattern = "*_L2R.nc"
img_list = []
for entry in listOfFiles:
    if fnmatch.fnmatch(entry, pattern):
            img_list.append(entry)
        
#img_dates = [i[8:18] for i in img_list] #for S2
img_dates = [i[7:17] for i in img_list] #for L8
number_of_images = len(img_list)
sat_dates = pd.DataFrame(data = img_dates, columns = ['Date'], index = range(0, number_of_images))
sat_dates['#img'] = range(0, number_of_images)
sat_dates.head()
# Out:
#          Date  #img
# 0  2014_07_16     0
# 1  2014_08_08     1
# 2  2014_08_17     2
# 3  2014_09_02     3
# 4  2014_09_25     4

# %%
sat_dates['Date'] = pd.to_datetime(sat_dates['Date'], format='%Y_%m_%d')

# %%
# create a dataframe from merging chla data and image names (based on same date)
merged_data = pd.merge(chl_data, sat_dates, on = 'Date')
merged_data
# Out:
#          Date  SiteNumber   latitude   Longitude   Lab_Chla  #img
# 0  2014-07-16           1  50.586139 -105.384833  43.878248     0
# 1  2014-08-08           1  50.586139 -105.384833  27.913994     1
# 2  2014-08-17           1  50.586139 -105.384833  47.813812     2
# 3  2014-09-02           1  50.586139 -105.384833  19.573582     3
# 4  2014-09-02           2  50.585203 -105.385823  15.000000     3
# ..        ...         ...        ...         ...        ...   ...
# 80 2019-07-14           1  50.586139 -105.384833  18.013329    60
# 81 2019-07-21           1  50.586139 -105.384833  52.015325    61
# 82 2019-08-22           1  50.586139 -105.384833  75.178461    62
# 83 2019-09-07           1  50.586139 -105.384833  55.694448    63
# 84 2019-09-16           1  50.586139 -105.384833  36.279784    64
#
# [85 rows x 6 columns]

# %%
# extracting reflectance values of correspond pixels to in-situ data
from netCDF4 import Dataset
Ref = [[]*0]*0
pixel = [[]*0]*0
for index, row in merged_data.iterrows():
    dataset = Dataset('../Data/L8_img_AC_acolite_2014-2019/' + img_list[merged_data.loc[index]['#img']])
    keys = dataset.variables.keys()
    dataset_1D = {}
    for key in keys:
        dataset_1D[key] = dataset.variables[key][:].flatten(order='C')

    dist = ((dataset_1D['lon'][:] - row['Longitude']) ** 2 + (dataset_1D['lat'][:] - row['latitude']) ** 2) ** (1/2) 
    idx_mins = dist.argsort()[:9]
    idx_min = idx_mins[1]
    
    pix_Y = idx_min // dataset.dimensions['x'].size
    pix_X = idx_min % dataset.dimensions['x'].size
    pix = [pix_Y, pix_X]
    pixel.append(pix)
    
    Rrs = []
    for key in keys:
        if 'rhos' in key:   #'Rrs'       
            Rrs.append((dataset_1D[key][idx_mins]).mean())
    Ref.append(Rrs)

# %%
RGB_layer = np.dstack((dataset.variables['rhos_655'][:],dataset.variables['rhos_561'][:],dataset.variables['rhos_443'][:]))
RGB_layer.shape
# Out:
# (812, 1186, 3)

# %%
from tkinter import *
from PIL import ImageTk, Image

# %%
im = Image.fromarray(np.uint8(RGB_layer*255)).convert('RGB')
im.show()

# %%
#global image
dataset = Dataset('../Data/L8_img_AC_acolite_2014-2019/' + img_list[merged_data.loc[2]['#img']])
RGB_layer = np.dstack((dataset.variables['rhos_655'][:],dataset.variables['rhos_561'][:],dataset.variables['rhos_443'][:]))
im2 = Image.fromarray(np.uint8(RGB_layer*255)).convert('RGB')

# %%
master = Tk()

img1 = ImageTk.PhotoImage(im1)
img2 = ImageTk.PhotoImage(im2)
img = [img1, img2]
img
# Out:
# [<PIL.ImageTk.PhotoImage at 0x16d89abd688>,
#  <PIL.ImageTk.PhotoImage at 0x16d89abd288>]

# %%
master = Tk()
  
# adding image (remember image should be PNG and not JPG) 

img1 = ImageTk.PhotoImage(im1)
img2 = ImageTk.PhotoImage(im2)
img = [img1, img2]

l1 = Label(image = img[0])
l1.grid(row = 1, column = 0, columnspan = 1, rowspan = 2, padx = 2, pady = 2)

def next(img_number):
#     global b4
#     global l1
    l1.grid_forget()
    l1 = Label(image = img[img_number-1]
    l1.grid(row = 1, column = 0, columnspan = 1, rowspan = 2, padx = 2, pady = 2)    

               
b4 = Button(master, text = "Next", command = lambda: next(1))
b4.grid(row = 0, column = 0, sticky = E)



               
mainloop()
# Out:
#   File "<ipython-input-180-7b11b3d35a2a>", line 18
#     label.grid(row = 1, column = 0, columnspan = 1, rowspan = 2, padx = 2, pady = 2)
#         ^
# SyntaxError: invalid syntax

# %%
import cv2

# %%
#dataset = Dataset('../Data/L8_img_AC_acolite_2014-2019/' + img_list[merged_data.loc[4]['#img']])
im_power_law_transformation = cv2.pow(RGB_layer,.5)
cv2.imshow('Original Image',RGB_layer)
cv2.imshow('Power Law Transformation',im_power_law_transformation)
plt.imshow(im_power_law_transformation)
#cv2.waitKey(0)

# %%
plt.imshow(RGB_layer)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# the result of above method to extract reflectance values was checked with PixEx method in SNAP. there is slight different in extracted pixelss. from 9 pixels extrscted 2 of them were different between two mwthods. but dont think it has much effect on results. also the above method put nan for if the window contains even one nan value. which I think makes sense to avoid adjacency effects of cloud and so on. however it can be replaced with nonmean mehthod.

# %%
# name of columns to add to dataframe
#added_ref = ['Rrs_443', 'Rrs_492', 'Rrs_560' , 'Rrs_665', 'Rrs_704', 'Rrs_740', 'Rrs_783', 'Rrs_833', 'Rrs_865', 'Rrs_1614' , 'Rrs_2202'] # for S2
added_ref = ['Rrs_443', 'Rrs_483', 'Rrs_561' , 'Rrs_655', 'Rrs_865', 'Rrs_1609', 'Rrs_2201'] # for L8

# %%
# crate a dataframe of ref data
sat_ref = pd.DataFrame(data = Ref, columns = added_ref)
sat_ref
# Out:
#      Rrs_443   Rrs_483   Rrs_561   Rrs_655   Rrs_865  Rrs_1609  Rrs_2201
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   0.005558  0.006397  0.009295  0.006070  0.008116  0.000151  0.000000
# 2        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3   0.001032  0.003280  0.008248  0.005194  0.001917  0.000002  0.000082
# 4   0.000728  0.003113  0.008034  0.005051  0.001633  0.000013  0.000088
# ..       ...       ...       ...       ...       ...       ...       ...
# 80       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 81  0.012710  0.013500  0.021525  0.011281  0.011394  0.000017  0.000135
# 82  0.002532  0.005881  0.015790  0.009050  0.005207  0.000000  0.000639
# 83       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 84       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# [85 rows x 7 columns]

# %% [markdown]
# # Merge sat and field data

# %%
# concating chla and ref dataframes 
samples = pd.concat([merged_data, pd.DataFrame(pixel,columns=['pix_Y','pix_X']), sat_ref], axis = 1)
print(samples.shape)
samples
# Out:
# (85, 15)
#          Date  SiteNumber   latitude   Longitude   Lab_Chla  #img  pix_Y  \
# 0  2014-07-16           1  50.586139 -105.384833  43.878248     0    684
# 1  2014-08-08           1  50.586139 -105.384833  27.913994     1    684
# 2  2014-08-17           1  50.586139 -105.384833  47.813812     2    684
# 3  2014-09-02           1  50.586139 -105.384833  19.573582     3    684
# 4  2014-09-02           2  50.585203 -105.385823  15.000000     3    687
# ..        ...         ...        ...         ...        ...   ...    ...
# 80 2019-07-14           1  50.586139 -105.384833  18.013329    60    684
# 81 2019-07-21           1  50.586139 -105.384833  52.015325    61    684
# 82 2019-08-22           1  50.586139 -105.384833  75.178461    62    684
# 83 2019-09-07           1  50.586139 -105.384833  55.694448    63    684
# 84 2019-09-16           1  50.586139 -105.384833  36.279784    64    684
#
#     pix_X   Rrs_443   Rrs_483   Rrs_561   Rrs_655   Rrs_865  Rrs_1609  \
# 0     982       NaN       NaN       NaN       NaN       NaN       NaN
# 1     982  0.005558  0.006397  0.009295  0.006070  0.008116  0.000151
# 2     982       NaN       NaN       NaN       NaN       NaN       NaN
# 3     982  0.001032  0.003280  0.008248  0.005194  0.001917  0.000002
# 4     979  0.000728  0.003113  0.008034  0.005051  0.001633  0.000013
# ..    ...       ...       ...       ...       ...       ...       ...
# 80    982       NaN       NaN       NaN       NaN       NaN       NaN
# 81    982  0.012710  0.013500  0.021525  0.011281  0.011394  0.000017
# 82    982  0.002532  0.005881  0.015790  0.009050  0.005207  0.000000
# 83    982       NaN       NaN       NaN       NaN       NaN       NaN
# 84    982       NaN       NaN       NaN       NaN       NaN       NaN
#
#     Rrs_2201
# 0        NaN
# 1   0.000000
# 2        NaN
# 3   0.000082
# 4   0.000088
# ..       ...
# 80       NaN
# 81  0.000135
# 82  0.000639
# 83       NaN
# 84       NaN
#
# [85 rows x 15 columns]

# %%
#drop missing values in ref 
samples.dropna(axis=0, inplace=True)
samples
# Out:
#          Date  SiteNumber   latitude   Longitude    Lab_Chla  #img   Rrs_443  \
# 1  2014-08-08           1  50.586139 -105.384833   27.913994     1  0.005540
# 2  2014-08-17           1  50.586139 -105.384833   47.813812     2  0.006232
# 62  0.006815  0.013105  0.007022  0.003633  0.000000  0.000285
# 63  0.008180  0.015704  0.008531  0.004249  0.000000  0.000362
# 64  0.008630  0.015443  0.009122  0.005077  0.000000  0.000316
# 65  0.005186  0.006561  0.004200  0.002434  0.000000  0.000127
# 66  0.004576  0.005422  0.003554  0.002442  0.000000  0.000155
# 67  0.003995  0.005518  0.003848  0.010348  0.000000  0.000196
# 68  0.007350  0.010046  0.007105  0.002849  0.000000  0.000385
# 69  0.014557  0.023342  0.018427  0.003860  0.000000  0.000442
# 70  0.016291  0.021954  0.014413  0.014403  0.000594  0.000000
# 71  0.005949  0.010929  0.008244  0.005918  0.000000  0.000337
# 72  0.004932  0.008067  0.003137  0.003229  0.000000  0.000417
# 73  0.003889  0.008092  0.004567  0.002710  0.000000  0.000631
# 74  0.003941  0.007750  0.004738  0.003002  0.000000  0.000504
# 75  0.004655  0.009955  0.005606  0.003171  0.000000  0.000417
# 76  0.004994  0.015809  0.007210  0.003744  0.000000  0.000359
# 77  0.008672  0.014849  0.008660  0.009417  0.000000  0.000074
# 78  0.007225  0.015725  0.008931  0.005483  0.000000  0.000072
# 79  0.006541  0.014644  0.008248  0.005374  0.000000  0.000474
# 80  0.015362  0.018663  0.013126  0.013979  0.000000  0.000022
# 81  0.008052  0.013525  0.007898  0.004955  0.000000  0.000133
# 84  0.014043  0.023840  0.012462  0.012063  0.000000  0.000064
# 85  0.005646  0.015655  0.009049  0.005241  0.000000  0.000666

# %% [markdown]
# # feature engineering

# %%
y = samples.Lab_Chla
X = samples.drop('Lab_Chla', axis = 1)
X.head()
# Out:
#         Date  SiteNumber   latitude   Longitude  #img   Rrs_443   Rrs_483  \
# 1 2014-08-08           1  50.586139 -105.384833     1  0.005540  0.006372
# 2 2014-08-17           1  50.586139 -105.384833     2  0.006232  0.006610
# 3 2014-09-02           1  50.586139 -105.384833     3  0.001037  0.003186
# 4 2014-09-02           2  50.585203 -105.385823     3  0.000691  0.003179
# 6 2015-05-23           1  50.586139 -105.384833     8  0.001779  0.002868
#
#     Rrs_561   Rrs_655   Rrs_865  Rrs_1609  Rrs_2201
# 1  0.009167  0.006044  0.008112  0.000165  0.000000
# 2  0.009521  0.005304  0.003543  0.000453  0.000000
# 3  0.008180  0.005115  0.001826  0.000000  0.000067
# 4  0.008161  0.005107  0.001627  0.000000  0.000075
# 6  0.004902  0.003020  0.002147  0.000000  0.000192

# %%
y_trans_log10 = np.log10(y)
len(y_trans_log10)
# Out:
# 55

# %%
# computing traditional models
X['NDCI'] = (X['Rrs_704']- X['Rrs_665']) / (X['Rrs_704']+  X['Rrs_665'])
X['M09'] = X['Rrs_704'] / X['Rrs_665']
#X['T07'] = X['Rrs_665'] / X['Rrs_560']
X['D05'] = (X['Rrs_665']**(-1) - X['Rrs_704']**(-1)) * X['Rrs_740']
X['OC2'] = X['Rrs_492'] / X['Rrs_560']
X['OC3'] = pd.concat([X['Rrs_492'],X['Rrs_443']], axis=1).max(axis=1) / X['Rrs_560']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\amchegoo\Anaconda3\envs\MDN\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rrs_704'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-232-8ab7a99dca19> in <module>()
#       1 # computing traditional models
# ----> 2 X['NDCI'] = (X['Rrs_704']- X['Rrs_665']) / (X['Rrs_704']+  X['Rrs_665'])
#       3 X['M09'] = X['Rrs_704'] / X['Rrs_665']
#       4 #X['T07'] = X['Rrs_665'] / X['Rrs_560']
#       5 X['D05'] = (X['Rrs_665']**(-1) - X['Rrs_704']**(-1)) * X['Rrs_740']
#
# C:\Users\amchegoo\Anaconda3\envs\MDN\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# C:\Users\amchegoo\Anaconda3\envs\MDN\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rrs_704'

# %%
selected_features = []
selected_features = added_ref[:6]
#selected_features.append('SiteNumber')
# selected_features.append('NDCI')
# selected_features.append('M09')
# selected_features.append('D05')
X_sel = pd.DataFrame(X[selected_features])
X_sel
# Out:
#      Rrs_443   Rrs_483   Rrs_561   Rrs_655   Rrs_865  Rrs_1609
# 1   0.005577  0.006382  0.009270  0.006066  0.008129  0.000153
# 3   0.001039  0.003282  0.008284  0.005233  0.001952  0.000000
# 4   0.000763  0.003132  0.008051  0.005083  0.001604  0.000013
# 6   0.001750  0.002876  0.004905  0.003055  0.002193  0.000000
# 7   0.002243  0.004267  0.010517  0.005284  0.003343  0.000000
# 8   0.002241  0.004270  0.010058  0.005135  0.003359  0.000000
# 9   0.002689  0.004469  0.009490  0.005172  0.003049  0.000000
# 19  0.001862  0.004112  0.010115  0.005387  0.002962  0.000000
# 20  0.001782  0.003887  0.009320  0.004943  0.002938  0.000000
# 21  0.001535  0.003834  0.009973  0.005172  0.004463  0.000006
# 22  0.003115  0.005312  0.013857  0.006990  0.004520  0.000000
# 23  0.018390  0.018283  0.019862  0.013578  0.016672  0.000706
# 24  0.003742  0.005696  0.011941  0.007045  0.008360  0.000310
# 25  0.007357  0.009126  0.015999  0.010156  0.004706  0.000000
# 26  0.002889  0.005449  0.014290  0.008248  0.005351  0.000000
# 29  0.005356  0.007308  0.015387  0.008922  0.011138  0.000000
# 30  0.002889  0.004678  0.010189  0.006617  0.005575  0.000000
# 37  0.002243  0.004390  0.008999  0.003962  0.002518  0.000000
# 38  0.002102  0.004508  0.009766  0.004262  0.002434  0.000000
# 43  0.004281  0.006498  0.014056  0.007690  0.006289  0.000034
# 44  0.002097  0.004754  0.013112  0.006661  0.004645  0.000007
# 51  0.005892  0.006610  0.007989  0.004192  0.002988  0.000032
# 52  0.007991  0.009156  0.014150  0.007317  0.002614  0.000000
# 53  0.001985  0.003471  0.008198  0.003970  0.003375  0.000000
# 54  0.002269  0.004418  0.010750  0.005818  0.002715  0.000000
# 55  0.002260  0.004488  0.010818  0.005975  0.002683  0.000000
# 56  0.012767  0.013551  0.019002  0.011966  0.011794  0.000000
# 57  0.012963  0.013759  0.019598  0.012361  0.012136  0.000000
# 58  0.012471  0.013542  0.019857  0.012515  0.012500  0.000000
# 59  0.007033  0.008883  0.018254  0.009534  0.005307  0.000000
# 61  0.003957  0.005119  0.009231  0.004562  0.003047  0.000000
# 62  0.004944  0.006801  0.013130  0.007017  0.003588  0.000000
# 63  0.005918  0.008155  0.015667  0.008513  0.004260  0.000000
# 64  0.006417  0.008599  0.015506  0.009176  0.004869  0.000000
# 65  0.004069  0.004983  0.006215  0.003929  0.002458  0.000000
# 66  0.003674  0.004457  0.005407  0.003469  0.002356  0.000000
# 67  0.003582  0.004013  0.005481  0.003801  0.010207  0.000000
# 68  0.006356  0.008180  0.011429  0.008100  0.002976  0.000000
# 69  0.009946  0.014093  0.022267  0.017488  0.003974  0.000000
# 70  0.015237  0.016363  0.021917  0.014423  0.014397  0.000558
# 71  0.003755  0.006106  0.010998  0.008309  0.005848  0.000000
# 73  0.002636  0.003913  0.008091  0.004571  0.002733  0.000000
# 74  0.002498  0.003785  0.007550  0.004558  0.002858  0.000000
# 75  0.003027  0.004528  0.009950  0.005521  0.003130  0.000000
# 76  0.002522  0.005145  0.015688  0.007296  0.003908  0.000000
# 77  0.007069  0.008607  0.014922  0.008758  0.009352  0.000000
# 78  0.005161  0.007204  0.015713  0.008869  0.005482  0.000000
# 79  0.004426  0.006605  0.014704  0.008253  0.005315  0.000000
# 80  0.014545  0.015446  0.018615  0.013265  0.014129  0.000005
# 81  0.006354  0.007891  0.013539  0.007870  0.004914  0.000000
# 84  0.012715  0.013483  0.021577  0.011313  0.011406  0.000025
# 85  0.002533  0.005837  0.015774  0.009032  0.005220  0.000000

# %%
# filt_outliers = X['Rrs_443'].between(X['Rrs_443'].quantile(.05), X['Rrs_443'].quantile(.95))
# X[filt_outliers].T.plot()
# X = X[filt_outliers]
# y = y[filt_outliers]

# %%
#from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_sel_standard = scaler.fit_transform(X_sel)
plt.hist(X_sel_standard)
# Out:
# (array([[ 1., 26., 13.,  4.,  1.,  5.,  1.,  1.,  0.,  0.],
#         [ 1., 25., 13.,  5.,  1.,  5.,  2.,  0.,  0.,  0.],
#         [ 6., 19.,  8., 10.,  6.,  3.,  0.,  0.,  0.,  0.],
#         [ 6., 17., 14.,  7.,  4.,  3.,  0.,  1.,  0.,  0.],
#         [ 1., 25., 14.,  3.,  4.,  4.,  1.,  0.,  0.,  0.],
#         [ 0.,  0., 48.,  1.,  0.,  1.,  0.,  0.,  1.,  1.]]),
#  array([-1.73010809, -1.03782843, -0.34554876,  0.34673091,  1.03901058,
#          1.73129024,  2.42356991,  3.11584958,  3.80812925,  4.50040892,
#          5.19268858]),
#  <a list of 6 Lists of Patches objects>)

# %% [markdown]
# # Model development

# %%
## import models
#from sklearn.tree import DecisionTreeRegressor
#from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
#from sklearn.svm import SVR
#from sklearn.linear_model import LinearRegression
#from sklearn.cross_decomposition import PLSRegression

#model = DecisionTreeRegressor(max_depth=100)
#model = RandomForestRegressor(n_estimators=100, random_state=0)
model = XGBRegressor(booster='dart',n_estimators=100, random_state=0, learning_rate = 0.1)
#model = SVR(kernel = 'rbf', gamma = 'scale')
#model = LinearRegression()
#model = PLSRegression(n_components = 4)

# %%
# create a pipeline
from sklearn.pipeline import Pipeline
my_pipeline = Pipeline(steps=[('model', model)])

# %%
# cross validation and accuracy assessment of model
from sklearn.model_selection import cross_val_score
mae = 10**(-1 * cross_val_score(my_pipeline, X_sel, y_trans_log10, cv=5, scoring='neg_mean_absolute_error').mean())
mae
# Out:
# 1.885551137662659

# %%
# getting predictions from cross validation
from sklearn.model_selection import cross_val_predict
y_pred = cross_val_predict(my_pipeline, X_sel, y_trans_log10, cv=5)

# %% [markdown]
# # Implement MDN

# %%
# prepare and save data to import to MDN
sat_ref_MDN = np.array(sat_ref.dropna(axis=0))[:,:7]
print(sat_ref_MDN)
np.savetxt("sat_ref_MDN.csv", sat_ref_MDN, delimiter=",")
# Out:
# [[-2.09765640e-04  2.31973897e-03  8.06056708e-03  2.00239499e-03
#    2.08752463e-03  1.21714722e-03  1.30019512e-03]
#  [-3.99375305e-04  2.58346763e-03  1.01522617e-02  2.96770618e-03
#    2.67801806e-03  1.90786261e-03  1.90896029e-03]
#  [ 9.48206696e-04  3.61236162e-03  1.06873764e-02  3.89533490e-03
#    3.82831879e-03  3.56730237e-03  3.54983029e-03]
#  [ 8.51780933e-04  3.12810019e-03  1.01393424e-02  3.63314780e-03
#    3.53770959e-03  3.55285197e-03  3.56430630e-03]
#  [ 1.49659170e-02  1.57210678e-02  1.99800078e-02  1.21579515e-02
#    1.49987200e-02  1.83660220e-02  1.79224927e-02]
#  [ 1.52818887e-02  1.60253663e-02  2.12811250e-02  1.33921690e-02
#    1.68580022e-02  1.95817556e-02  1.89502686e-02]
#  [ 1.06544383e-02  1.25398366e-02  1.69702452e-02  1.03156148e-02
#    1.25483228e-02  1.72038171e-02  1.82624850e-02]
#  [ 1.07370235e-03  3.94613715e-03  1.22233583e-02  5.90970926e-03
#    7.70800002e-03  4.24789498e-03  3.84034286e-03]
#  [ 7.11516710e-04  3.70116881e-03  1.20223342e-02  5.85199846e-03
#    7.68475188e-03  4.20691120e-03  4.08636359e-03]
#  [ 3.32072563e-03  7.20951753e-03  2.01827846e-02  8.98568984e-03
#    2.04481035e-02  1.02602383e-02  9.73785389e-03]
#  [ 8.42144480e-04  4.48148651e-03  1.47179617e-02  6.47292659e-03
#    1.24487504e-02  5.50159300e-03  4.99630673e-03]
#  [ 7.21045583e-03  9.41875577e-03  1.47350244e-02  1.02310963e-02
#    1.18662985e-02  9.68522951e-03  9.00160894e-03]
#  [ 1.15813233e-03  4.19267965e-03  8.76325462e-03  4.90363548e-03
#    4.63040778e-03  2.70242500e-03  2.88365968e-03]
#  [-2.13123742e-04  2.50081136e-03  6.62099943e-03  1.69281801e-03
#    1.18320738e-03  9.28560039e-04  1.14342559e-03]
#  [ 1.03316261e-05  2.53637880e-03  5.68366656e-03  1.95271836e-03
#    1.45669060e-03  1.35924574e-03  1.46197202e-03]
#  [ 2.79388856e-03  2.78387894e-03  4.92016692e-03  1.39107334e-03
#    1.65348547e-03  2.73936428e-03  2.35593040e-03]
#  [ 1.52984122e-03  4.43725614e-03  8.62095226e-03  2.42158654e-03
#    2.20434158e-03  3.88109009e-03  4.11379104e-03]
#  [ 4.28794650e-04  2.10506283e-03  8.51362851e-03  2.65636016e-03
#    2.41999910e-03  2.19931290e-03  2.15434073e-03]
#  [ 3.87921813e-03  7.41556240e-03  2.06227358e-02  8.42377637e-03
#    1.88612323e-02  1.02463011e-02  1.03168711e-02]
#  [ 1.72432803e-03  5.00171678e-03  1.49527611e-02  6.76572323e-03
#    1.30159343e-02  7.16135139e-03  6.53475150e-03]]

# %%
# Run MDN 
! python -m MDN --sensor S2A sat_ref_MDN.csv
# Out:
# Min Rrs: [-0.00177937  0.00084586  0.00492017  0.00109415  0.00117368  0.00092856
#   0.00099052]
# Max Rrs: [0.01528189 0.01602537 0.02183341 0.01489365 0.02050217 0.01958176
#  0.01895027]
# Generating estimates for 85 data points
# Min: [5.209888]
# Max: [157.77429]
# Saving estimates at location "MDN_sat_ref_MDN.csv"
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|#         | 1/10 [00:03<00:33,  3.68s/it]
#  20%|##        | 2/10 [00:07<00:28,  3.61s/it]
#  30%|###       | 3/10 [00:10<00:25,  3.58s/it]
#  40%|####      | 4/10 [00:14<00:21,  3.56s/it]
#  50%|#####     | 5/10 [00:17<00:17,  3.56s/it]
#  60%|######    | 6/10 [00:21<00:14,  3.56s/it]
#  70%|#######   | 7/10 [00:24<00:10,  3.50s/it]
#  80%|########  | 8/10 [00:28<00:07,  3.57s/it]
#  90%|######### | 9/10 [00:31<00:03,  3.58s/it]
# 100%|##########| 10/10 [00:35<00:00,  3.50s/it]
# 100%|##########| 10/10 [00:35<00:00,  3.53s/it]

# %%
# read the output of MDN model and make format consistent with other models' outputs 
y_pred = pd.read_csv('MDN_sat_ref_MDN.csv')
y_pred = np.transpose(np.array(np.log10(y_pred)))
y_pred
# Out:
# array([[1.32628516, 1.248368  , 1.07146654, 1.13672469, 1.71897503,
#         1.83735583, 1.74451895, 1.68740277, 1.66135705, 2.14498798,
#         2.14030194, 1.95234145, 1.11372528, 0.71682839, 0.89824412,
#         0.98115398, 0.7353698 , 1.23906635, 1.15433708, 1.9059268 ,
#         2.16703072, 2.18350695, 2.19803623, 2.05738578, 1.6874759 ,
#         1.72284978, 0.93889177, 1.91344025, 1.61222741, 1.25280851,
#         1.17368897, 1.20888663, 1.19518439, 1.28083648, 1.33932414,
#         1.4143271 , 1.15228623, 1.6252262 , 1.541398  , 1.53679623,
#         1.38158262, 1.60601109, 2.04428899, 1.61088949, 1.79297526,
#         1.59594979, 1.74128368, 1.71188655, 1.75027719, 1.7917345 ,
#         1.63098457, 1.64834469, 1.46393903, 1.46433737, 1.06693098,
#         1.18049051, 1.21849186, 1.15069011, 1.24556313, 1.2412626 ,
#         1.30043354, 0.87604632, 1.4329483 , 1.19412375, 1.26983371,
#         1.67695064, 1.69038734, 1.77712304, 1.89343548, 1.98199664,
#         1.47343796, 1.26516182, 0.84286887, 1.34735266, 1.45953883,
#         1.32553475, 1.63922733, 1.17377901, 0.77146893, 1.94004513,
#         2.14297284, 2.09326188, 2.18941622, 2.15505104, 2.17033032]])

# %% [markdown]
# # bst_oli (Cao et al., 2020)

# %%
# Rayleigh-corrected reflectance should be intrudeced to the model as input
import xgboost as xgb
bst = xgb.Booster({'nthread': 4})  # init model
bst.load_model('bst_oli\chl_bst_model_release.model')  # load data
dtest = xgb.DMatrix(X_sel_standard)
y_pred = np.log10(bst.predict(dtest))
y_pred
# Out:
# array([1.1650392 , 1.0744643 , 1.0744643 , 1.0744643 , 1.0744643 ,
#        1.0744643 , 1.0744643 , 1.0744643 , 1.0744643 , 1.0744643 ,
#        0.8818123 , 1.2071403 , 1.3295841 , 0.8071258 , 0.9239095 ,
#        1.384474  , 1.0663232 , 1.0744643 , 1.0744643 , 1.4082023 ,
#        0.87151104, 1.045853  , 0.7856911 , 1.0744643 , 1.0744643 ,
#        1.0744643 , 0.99658287, 0.99658287, 0.99658287, 0.8071258 ,
#        1.0744643 , 0.8658826 , 0.8071258 , 0.8071258 , 1.0744643 ,
#        1.0744643 , 1.4556514 , 0.9858441 , 0.8071258 , 1.2071403 ,
#        1.449587  , 1.0744643 , 1.0744643 , 1.0744643 , 0.8818123 ,
#        0.99658287, 0.94254756, 0.9239095 , 0.99658287, 0.8071258 ,
#        0.99658287, 0.9239095 ], dtype=float32)

# %% [markdown]
# # validation performance

# %%
from scipy.io import savemat
savemat('y_pred.mat', {'y_pred': y_pred})
#y_trans_log10[y_trans_log10 == 0] = 0.05
savemat('y.mat', {'y': np.array(y_trans_log10)})

# %%
img_list[62]

# %%
from netCDF4 import Dataset
#Ref = [[]*0]*0 
#for index, row in merged_data.iterrows():
dataset = Dataset('../S2_img_AC_acolite_2014-2019/' + img_list[62])
keys = dataset.variables.keys()
dataset_1D = {}
for key in keys:
    dataset_1D[key] = dataset.variables[key][:].flatten()

# %%
Ref = [[]*0]*0 
for i in range(0,len(dataset_1D['lat'])):
    if dataset_1D['l2_flags'][i] == 0:
        Rrs = []
        for key in keys:
            if 'Rrs' in key:        
                Rrs.append(dataset_1D[key][i])
        Ref.append(Rrs)
        
ww = (np.array(Ref))   
ww = ww[:, :6]

# %%
ww

# %%
# from sklearn.preprocessing import scale 
# ww_scaled = scale(ww)
# ww_scaled

# %%
def reject_outliers(data, m):
    return abs(data - np.median(data)) > m * np.std(data)

idx = ww.copy()
for i in range(0, ww.shape[1]):
    data = ww[:,i]
    idx[:,i] = reject_outliers(data, 2)

idx_outlier = idx.sum(axis=1) != 0

# %%
sum(idx_outlier)

# %%
ww

# %%
model.fit(X, y_trans_log10)
values_pred = model.predict(ww)
idx_values_pred_outlier = reject_outliers(values_pred, 2)
values_pred[idx_values_pred_outlier] = 'NaN'
values_pred_unlog = 10 ** values_pred
values_pred_unlog[idx_outlier] = 'NaN'

# %%
sum(idx_values_pred_outlier)

# %%
image_flat = np.array(dataset_1D['Rrs_492']) 
idx = np.isnan(image_flat)
image_flat[~idx]= values_pred_unlog

# %%
image = image_flat.reshape(dataset.dimensions['y'].size, dataset.dimensions['x'].size)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

ax = plt.figure(figsize = [16,12])
heatmap = plt.imshow(image, cmap='jet', interpolation='nearest')

cbar = plt.colorbar(heatmap, cax = ax.add_axes([.15, 0.15, 0.03, 0.7]))
cbar.ax.tick_params(labelsize=20)

# %%
ax.savefig('SVR_62.png',dpi=500, format='png')
